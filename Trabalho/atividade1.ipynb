# %%
import seaborn as sns
from scipy import stats

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\d6684\Desktop\Heloisa\funcionarios_empresa.csv")

# %%
print(df.info())
## avaliação, nivel educacao, beneficios, satisfaçao
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID_Funcionario         500 non-null    int64
#  1   Nome                   500 non-null    object
#  2   Idade                  500 non-null    int64
#  3   Departamento           500 non-null    object
#  4   Cargo                  500 non-null    object
#  5   Salario                500 non-null    float64
#  6   Tempo_Empresa_Meses    500 non-null    int64
#  7   Data_Admissao          500 non-null    object
#  8   Nivel_Educacao         495 non-null    object
#  9   Estado_Civil           500 non-null    object
#  10  Tipo_Contrato          500 non-null    object
#  11  Avaliacao_Performance  475 non-null    float64
#  12  Horas_Extras_Mes       500 non-null    int64
#  13  Beneficios             490 non-null    float64
# ...

# %%
print(df.describe)
# Out:
# <bound method NDFrame.describe of      ID_Funcionario                Nome  Idade Departamento  \
# 0                 1  Tatiane Mendes 001     40       Vendas
# 1                 2       Ana Silva 002     23    Marketing
# 2                 3    Rafael Alves 003     36           TI
# 3                 4     Carla Souza 004     32    Operações
# 4                 5     Pedro Costa 005     33   Financeiro
# ..              ...                 ...    ...          ...
# 495             496  Bruno Ferreira 496     25       Vendas
# 496             497   Felipe Araújo 497     27       Vendas
# 497             498   Felipe Araújo 498     42    Operações
# 498             499     Pedro Costa 499     32    Marketing
# 499             500  Tatiane Mendes 500     35    Marketing
#
#                            Cargo  Salario  Tempo_Empresa_Meses Data_Admissao  \
# 0                    Vendedor Jr  3685.36                    4    2025-05-18
# ...

# %%
print(df)
# Out:
#      ID_Funcionario                Nome  Idade Departamento  \
# 0                 1  Tatiane Mendes 001     40       Vendas
# 1                 2       Ana Silva 002     23    Marketing
# 2                 3    Rafael Alves 003     36           TI
# 3                 4     Carla Souza 004     32    Operações
# 4                 5     Pedro Costa 005     33   Financeiro
# ..              ...                 ...    ...          ...
# 495             496  Bruno Ferreira 496     25       Vendas
# 496             497   Felipe Araújo 497     27       Vendas
# 497             498   Felipe Araújo 498     42    Operações
# 498             499     Pedro Costa 499     32    Marketing
# 499             500  Tatiane Mendes 500     35    Marketing
#
#                            Cargo  Salario  Tempo_Empresa_Meses Data_Admissao  \
# 0                    Vendedor Jr  3685.36                    4    2025-05-18
# 1       Coordenador de Marketing  8081.03                    1    2025-08-16
# ...

# %%
print(df[df['Nivel_Educacao'].isnull()])
# Out:
#      ID_Funcionario                Nome  Idade Departamento  \
# 23               24   Felipe Araújo 024     32   Financeiro
# 116             117  Vanessa Castro 117     37           TI
# 135             136   Marcelo Cunha 136     34    Marketing
# 145             146   Vinícius Melo 146     36           TI
# 207             208  André Teixeira 208     32           TI
#
#                         Cargo   Salario  Tempo_Empresa_Meses Data_Admissao  \
# 23                   Contador   8152.92                    3    2025-06-17
# 116             Gerente de TI  17356.46                    1    2025-08-16
# 135  Analista de Marketing Jr   3277.16                   12    2024-09-20
# 145          Desenvolvedor Jr   3700.59                   10    2024-11-19
# 207             Gerente de TI  14030.99                   41    2022-05-04
#
#     Nivel_Educacao Estado_Civil Tipo_Contrato  Avaliacao_Performance  \
# 23             NaN    Casado(a)            PJ                    4.2
# ...

# %%
print(df['Nivel_Educacao'].mode())
##Moda da coluna nive leducação é superior completo
# Out:
# 0    Superior Completo
# Name: Nivel_Educacao, dtype: object

# %%
df['Nivel_Educacao'] = df['Nivel_Educacao'].fillna("Superior Completo")
##Substituir os valores nulos da coluna nivel educacao pela moda superior completo

# %%
print(df[df['Nivel_Educacao'].isnull()])
# Out:
# Empty DataFrame
# Columns: [ID_Funcionario, Nome, Idade, Departamento, Cargo, Salario, Tempo_Empresa_Meses, Data_Admissao, Nivel_Educacao, Estado_Civil, Tipo_Contrato, Avaliacao_Performance, Horas_Extras_Mes, Beneficios, Faltas_Ultimo_Ano, Satisfacao_Trabalho]
# Index: []

# %%
print(df['Avaliacao_Performance'].mean())
print(df['Beneficios'].mean())
print(df['Satisfacao_Trabalho'].mean())
# Out:
# 3.4273684210526314
# 811.2002244897959
# 7.023092783505154

# %%
df['Avaliacao_Performance']=df['Avaliacao_Performance'].fillna(3.4273684210526314)
df['Beneficios']=df['Beneficios'].fillna(811.2002244897959)
df['Satisfacao_Trabalho']=df['Satisfacao_Trabalho'].fillna(7.023092783505154)

# %%
import numpy as np
import matplotlib.pyplot as  plt      
import seaborn as sns

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x=df['Beneficios'])
plt.title(' ')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=df['Salario'])
plt.title(' ')
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x=df['Avaliacao_Performance'])
plt.title(' ')
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x=df['Satisfacao_Trabalho'])
plt.title(' ')
plt.show()

# %%
colunas_numericas = ['Idade','Salario','Tempo_Empresa_Meses','Avaliacao_Performance',
                     'Horas_Extras_Mes','Beneficios','Faltas_Ultimo_Ano','Satisfacao_Trabalho']

for col in colunas_numericas:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    limite_inf = Q1 - 1.5 * IQR
    limite_sup = Q3 + 1.5 * IQR

    outliers = df[(df[col] < limite_inf) | (df[col] > limite_sup)]
    print(f'Coluna: {col} | Outliers encontrados: {len(outliers)}')
# Out:
# Coluna: Idade | Outliers encontrados: 20
# Coluna: Salario | Outliers encontrados: 5
# Coluna: Tempo_Empresa_Meses | Outliers encontrados: 28
# Coluna: Avaliacao_Performance | Outliers encontrados: 8
# Coluna: Horas_Extras_Mes | Outliers encontrados: 23
# Coluna: Beneficios | Outliers encontrados: 4
# Coluna: Faltas_Ultimo_Ano | Outliers encontrados: 2
# Coluna: Satisfacao_Trabalho | Outliers encontrados: 3

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x=df['Idade'])
plt.title(' ')
plt.show()
